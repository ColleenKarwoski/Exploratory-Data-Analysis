# %%
#Goal: 
#Find all sales > $100K and color by make, size by price
#Translate zip to lat/long to locate sales
#Use API to determine closest car repair shop to car sales

#import dependencies (hvpolt for mapping later)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import hvplot.pandas

#Import API key
from api_key import api_key

#load clean car data into new DataFrame
cleaned_car_data = "Resources/cleaned_used_car_data.csv"
zip_to_latlng = "Resources/100K_or_above_zip_geocodio.csv"

#read CSV file and store in Pandas DataFrame
df = pd.read_csv(cleaned_car_data)
zip_df = pd.read_csv(zip_to_latlng)

#show df
df.head()
# Out:
#    Unnamed: 0      ID  pricesold  yearsold  zipcode  Mileage        Make  \
# 0           2  119660       8750      2020    33449    55000      Jaguar
# 1           3   80773      11600      2019     7852    97200        Ford
# 2           4   64287      44000      2019     7728    40703     Porsche
# 3           7    5250      70000      2019     7627     6500  Land Rover
# 4           8   29023       1330      2019     7043   167000       Honda
#
#       Model  Year           Trim                      Engine     BodyType  \
# 0       XJS  1995  2+2 Cabriolet     4.0L In-Line 6 Cylinder  Convertible
# 1   Mustang  1968          Stock              289 cu. in. V8        Coupe
# 2       911  2002     Turbo X-50                        3.6L        Coupe
# 3  Defender  1997            NaN  4.0 Liter Fuel Injected V8          NaN
# 4     Civic  2001             EX                         NaN        Coupe
#
#    NumCylinders DriveType
# 0             6       RWD
# 1             8       RWD
# 2             6       AWD
# 3             0       4WD
# 4             4       FWD

# %%
zip_df.head()
# Out:
#    zipcode   Latitude   Longitude  Accuracy Score Accuracy Type  Number  \
# 0    33144  25.763484  -80.312095             0.9         place     NaN
# 1    33144  25.763484  -80.312095             0.9         place     NaN
# 2    33144  25.763484  -80.312095             0.9         place     NaN
# 3    81505  39.146570 -108.626481             1.0         place     NaN
# 4    85755  32.452638 -110.973660             0.9         place     NaN
#
#    Street  Unit Type  Unit Number            City State             County  \
# 0     NaN        NaN          NaN           Miami    FL  Miami-Dade County
# 1     NaN        NaN          NaN           Miami    FL  Miami-Dade County
# 2     NaN        NaN          NaN           Miami    FL  Miami-Dade County
# 3     NaN        NaN          NaN  Grand Junction    CO        Mesa County
# 4     NaN        NaN          NaN      Oro Valley    AZ        Pima County
#
#      Zip Country                                         Source
# 0  33144      US  TIGER/Line® dataset from the US Census Bureau
# 1  33144      US  TIGER/Line® dataset from the US Census Bureau
# 2  33144      US  TIGER/Line® dataset from the US Census Bureau
# 3  81505      US  TIGER/Line® dataset from the US Census Bureau
# 4  85755      US  TIGER/Line® dataset from the US Census Bureau

# %%
#create DataFrame for cars > $100K
rich_df = df[df['pricesold'] > 100000]

#show df
rich_df
# Out:
#        Unnamed: 0      ID  pricesold  yearsold  zipcode  Mileage  \
# 626          1153  112102     152500      2020    33144    13682
# 629          1157   73392     114600      2020    33144    23885
# 630          1158   51606     129800      2019    33144    18800
# 1881         3546   67708     119000      2019    81505     1152
# 3403         6196   45189     125000      2019    85755    16190
# ...           ...     ...        ...       ...      ...      ...
# 64356      114179   34409     241110      2019    91006     2719
# 66843      118420   26566     104600      2019    85250     4783
# 68297      120885   20441     135000      2019    44023       21
# 68593      121450   98215     107250      2019    32004    12500
# 68821      121900   98095     149300      2019    64801     3270
#
#                 Make        Model  Year                        Trim  \
# 626          Porsche          911  2011                         NaN
# 629          Porsche          911  2014           2dr Coupe Turbo S
# 630          Porsche          911  2015                         NaN
# 1881       Chevrolet     Corvette  1957                         NaN
# 3403   Mercedes-Benz      SLS AMG  2011              Gullwing Coupe
# ...              ...          ...   ...                         ...
# 64356  Mercedes-Benz  SLR McLaren  2005                Silver Arrow
# 66843        Porsche          911  2015                    Targa 4S
# 68297      Chevrolet       Impala  1959                         NaN
# 68593        Porsche          911  2010  Black w. Full Leather Trim
# 68821  Mercedes-Benz      SLS AMG  2011           Carbon Fiber Tri,
#
#                                      Engine            BodyType  NumCylinders  \
# 626                                     NaN               Coupe             6
# 629                                     NaN               Coupe             6
# 630                                     NaN               Coupe             6
# 1881                      383 fuel injected                 NaN             0
# 3403                      6.3 Liter DOHC V8               Coupe             8
# ...                                     ...                 ...           ...
# 64356                                     8               Coupe             8
# 66843                             3.8 Liter         Convertible             6
# 68297                                   348                 NaN             0
# 68593  3.8L 3824CC H6 GAS DOHC Turbocharged  Torbo Coupe 2-Door             6
# 68821                                   NaN               Coupe             8
#
#         DriveType
# 626           NaN
# 629           NaN
# 630           NaN
# 1881          NaN
# 3403          RWD
# ...           ...
# 64356         RWD
# 66843         AWD
# 68297         RWD
# 68593         AWD
# 68821  Rear Wheel
#
# [86 rows x 14 columns]

# %%
#merge rich_df with zip_df
rich_zip_df = pd.merge(rich_df,zip_df, on="zipcode")

#confirm lat/long in new DataFrame
rich_zip_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'pricesold', 'yearsold', 'zipcode', 'Mileage',
#        'Make', 'Model', 'Year', 'Trim', 'Engine', 'BodyType', 'NumCylinders',
#        'DriveType', 'Latitude', 'Longitude', 'Accuracy Score', 'Accuracy Type',
#        'Number', 'Street', 'Unit Type', 'Unit Number', 'City', 'State',
#        'County', 'Zip', 'Country', 'Source'],
#       dtype='object')

# %%
# Create map of car locations
map_plot = rich_zip_df.hvplot.points(
    'Longitude',
    'Latitude',
    hover_cols = ["Make","Model","pricesold"],
    geo = True,
    tiles = "OSM",
    scale = .02,
    color = "Make",
    size = "pricesold",
    frame_width = 800,
    frame_height = 500
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (Make,pricesold,Model)

# %%
rich_zip_df['Car Repair Shop Name'] = ''

# %%
#Set parameters for nearest car repair shop location
radius = 24140
params = {"categories": "service.vehicle.repair.car", "api_key":api_key}

# Print a message to follow up the car repair shop search
print("Searching for the closest car repair shop...")

#Iterate through rich_zip_df
for index, row in rich_zip_df.iterrows():
    # get latitude, longitude from the DataFrame
    Latitude = row["Latitude"]
    Longitude = row["Longitude"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Longitude},{Latitude},{radius}"
    params["bias"] = f"proximity:{Longitude},{Latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first repair shop from the results and store the name in the rich_zip_df DataFrame
    try:
        rich_zip_df.loc[index, "Car Repair Shop Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no repair shop is found, set the shop name as "No shop found".
        rich_zip_df.loc[index, "Car Repair Shop Name"] = "No shop found"
        
    # Log the search results
    print(f"{rich_zip_df.loc[index, 'zipcode']} - nearest repair shop: {rich_zip_df.loc[index, 'Car Repair Shop Name']}")
          
# Display sample data
rich_zip_df
# Out:
# Searching for the closest car repair shop...
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 33144 - nearest repair shop: West Miami Paint and Body Shop
# 81505 - nearest repair shop: High Horsepower Diesel & Machine
# 85755 - nearest repair shop: Vistoso Automotive
# 33180 - nearest repair shop: Mobil 1 Lube Express
# 38372 - nearest repair shop: No shop found
# 30309 - nearest repair shop: Auto Glass Atlanta
# 90064 - nearest repair shop: Pep Boys
# 85260 - nearest repair shop: Cactus Window Tint
# 85260 - nearest repair shop: Cactus Window Tint
# 85260 - nearest repair shop: Cactus Window Tint
# 85260 - nearest repair shop: Cactus Window Tint
# 83642 - nearest repair shop: Christian Brothers Automotive
# 90049 - nearest repair shop: Westside Mercedes
# 71115 - nearest repair shop: Firestone
# 94109 - nearest repair shop: Reliable Auto Body
# 11023 - nearest repair shop: Maple Place Garage
# 90068 - nearest repair shop: No shop found
# 85318 - nearest repair shop: Xpress Automotive
# 77380 - nearest repair shop: McKay's Automotive
# 92677 - nearest repair shop: South Coast Window Tinting
# 89116 - nearest repair shop: Purrfect Auto Service
# 34480 - nearest repair shop: Auto Masters
# 84119 - nearest repair shop: Pep Boys
# 84119 - nearest repair shop: Pep Boys
# 84119 - nearest repair shop: Pep Boys
# 84119 - nearest repair shop: Pep Boys
# 68031 - nearest repair shop: Sid Dillon Buick GMC Cadillac
# 33487 - nearest repair shop: Boca Auto Fix
# 33487 - nearest repair shop: Boca Auto Fix
# 33487 - nearest repair shop: Boca Auto Fix
# 33487 - nearest repair shop: Boca Auto Fix
# 97333 - nearest repair shop: B&R Auto Body
# 97333 - nearest repair shop: B&R Auto Body
# 97333 - nearest repair shop: B&R Auto Body
# 97333 - nearest repair shop: B&R Auto Body
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 11968 - nearest repair shop: Cisneros Tire Center
# 91355 - nearest repair shop: Enterprise
# 28262 - nearest repair shop: Precision Tune Auto Care
# 33073 - nearest repair shop: No shop found
# 7094 - nearest repair shop: No shop found
# 77090 - nearest repair shop: Auto Check
# 77090 - nearest repair shop: Auto Check
# 77090 - nearest repair shop: Auto Check
# 77090 - nearest repair shop: Auto Check
# 33716 - nearest repair shop: U PULL-R-PART
# 77836 - nearest repair shop: No shop found
# 62269 - nearest repair shop: Dobbs
# 77005 - nearest repair shop: Firestone
# 90272 - nearest repair shop: Santa Monica Brake
# 87048 - nearest repair shop: Pep Boys
# 60010 - nearest repair shop: Hollis Brother's Services
# 92651 - nearest repair shop: Autobaun Imports Auto Service Center
# 11791 - nearest repair shop: Syosset Tire & Auto Repair
# 61109 - nearest repair shop: Classic Auto Repair
# 21075 - nearest repair shop: Dependable Auto
# 34240 - nearest repair shop: Coastal Auto Collision & Customs
# 33928 - nearest repair shop: The Tire Choice & Total Car Care
# 63901 - nearest repair shop: Larry Hillis Body Shop
# 63901 - nearest repair shop: Larry Hillis Body Shop
# 63901 - nearest repair shop: Larry Hillis Body Shop
# 63901 - nearest repair shop: Larry Hillis Body Shop
# 32128 - nearest repair shop: Firestone
# 75225 - nearest repair shop: No shop found
# 60559 - nearest repair shop: No shop found
# 91361 - nearest repair shop: Firestone
# 10583 - nearest repair shop: Hartsdale Automotive
# 75205 - nearest repair shop: Texaco Service Center
# 91745 - nearest repair shop: Peng Complete Auto Services
# 33181 - nearest repair shop: Valvoline Instant Oil Change
# 34243 - nearest repair shop: No shop found
# 76108 - nearest repair shop: HOLT Truck Centers Fort Worth
# 46013 - nearest repair shop: Jiffy Lube
# 32309 - nearest repair shop: Stewart's
# 77079 - nearest repair shop: No shop found
# 95630 - nearest repair shop: America's Tire Warehouse
# 68117 - nearest repair shop: AAMCO
# 28205 - nearest repair shop: Take 5
# 38120 - nearest repair shop: Jiffy Lube
# 8034 - nearest repair shop: Goodyear
# 33931 - nearest repair shop: Scotty's Automotive
# 63701 - nearest repair shop: Carstar Russom's Cape Girardeau
# 33133 - nearest repair shop: Jiffy Lube
# 53020 - nearest repair shop: Fast Track Oil Change Center
# 7030 - nearest repair shop: Rabbit Juanrry Auto Body Shop
# 32962 - nearest repair shop: J&J Auto Works
# 33414 - nearest repair shop: ROYAL PALM AUTO SPA
# 83815 - nearest repair shop: Sears Auto
# 92782 - nearest repair shop: Valvoline Express Care
# 91006 - nearest repair shop: Homer's Auto Services
# 85250 - nearest repair shop: Firestone
# 44023 - nearest repair shop: Phillips Automotive
# 32004 - nearest repair shop: Quick Lane Tire & Auto
# 64801 - nearest repair shop: Autoglass Outlet and Tires
#      Unnamed: 0      ID  pricesold  yearsold  zipcode  Mileage           Make  \
# 0          1153  112102     152500      2020    33144    13682        Porsche
# 1          1153  112102     152500      2020    33144    13682        Porsche
# 2          1153  112102     152500      2020    33144    13682        Porsche
# 3          1153  112102     152500      2020    33144    13682        Porsche
# 4          1157   73392     114600      2020    33144    23885        Porsche
# ..          ...     ...        ...       ...      ...      ...            ...
# 111      114179   34409     241110      2019    91006     2719  Mercedes-Benz
# 112      118420   26566     104600      2019    85250     4783        Porsche
# 113      120885   20441     135000      2019    44023       21      Chevrolet
# 114      121450   98215     107250      2019    32004    12500        Porsche
# 115      121900   98095     149300      2019    64801     3270  Mercedes-Benz
#
#            Model  Year                        Trim  ... Street Unit Type  \
# 0            911  2011                         NaN  ...    NaN       NaN
# 1            911  2011                         NaN  ...    NaN       NaN
# 2            911  2011                         NaN  ...    NaN       NaN
# 3            911  2011                         NaN  ...    NaN       NaN
# 4            911  2014           2dr Coupe Turbo S  ...    NaN       NaN
# ..           ...   ...                         ...  ...    ...       ...
# 111  SLR McLaren  2005                Silver Arrow  ...    NaN       NaN
# 112          911  2015                    Targa 4S  ...    NaN       NaN
# 113       Impala  1959                         NaN  ...    NaN       NaN
# 114          911  2010  Black w. Full Leather Trim  ...    NaN       NaN
# 115      SLS AMG  2011           Carbon Fiber Tri,  ...    NaN       NaN
#
#      Unit Number               City  State              County    Zip Country  \
# 0            NaN              Miami     FL   Miami-Dade County  33144      US
# 1            NaN              Miami     FL   Miami-Dade County  33144      US
# 2            NaN              Miami     FL   Miami-Dade County  33144      US
# 3            NaN              Miami     FL   Miami-Dade County  33144      US
# 4            NaN              Miami     FL   Miami-Dade County  33144      US
# ..           ...                ...    ...                 ...    ...     ...
# 111          NaN            Arcadia     CA  Los Angeles County  91006      US
# 112          NaN         Scottsdale     AZ     Maricopa County  85250      US
# 113          NaN      Chagrin Falls     OH       Geauga County  44023      US
# 114          NaN  Ponte Vedra Beach     FL    St. Johns County  32004      US
# 115          NaN             Joplin     MO       Jasper County  64801      US
#
#                                             Source  \
# 0    TIGER/Line® dataset from the US Census Bureau
# 1    TIGER/Line® dataset from the US Census Bureau
# 2    TIGER/Line® dataset from the US Census Bureau
# 3    TIGER/Line® dataset from the US Census Bureau
# 4    TIGER/Line® dataset from the US Census Bureau
# ..                                             ...
# 111  TIGER/Line® dataset from the US Census Bureau
# 112  TIGER/Line® dataset from the US Census Bureau
# 113  TIGER/Line® dataset from the US Census Bureau
# 114  TIGER/Line® dataset from the US Census Bureau
# 115  TIGER/Line® dataset from the US Census Bureau
#
#                Car Repair Shop Name
# 0    West Miami Paint and Body Shop
# 1    West Miami Paint and Body Shop
# 2    West Miami Paint and Body Shop
# 3    West Miami Paint and Body Shop
# 4    West Miami Paint and Body Shop
# ..                              ...
# 111           Homer's Auto Services
# 112                       Firestone
# 113             Phillips Automotive
# 114          Quick Lane Tire & Auto
# 115      Autoglass Outlet and Tires
#
# [116 rows x 29 columns]

# %%
map_plot2 = rich_zip_df.hvplot.points(
    "Longitude",
    "Latitude",
    hover_cols=['Car Repair Shop Name'],
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 500,
    marker = 'star',
    color = 'City'
)

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Car Repair Shop Name)
