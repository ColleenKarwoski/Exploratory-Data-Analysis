# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import scipy.stats as st
from scipy.stats import linregress

# %%
data = "Resources/cleaned_used_car_data.csv"
zipcode_data = "Resources/Zip_Locale_Detail.csv"

# Read CSV file and store in Pandas DataFrame
cleaned_df = pd.read_csv(data)
zip_df = pd.read_csv(zipcode_data)

# Show df
cleaned_df.head()
# Out:
#    Unnamed: 0      ID  pricesold  yearsold  zipcode  Mileage        Make  \
# 0           2  119660       8750      2020    33449    55000      Jaguar
# 1           3   80773      11600      2019     7852    97200        Ford
# 2           4   64287      44000      2019     7728    40703     Porsche
# 3           7    5250      70000      2019     7627     6500  Land Rover
# 4           8   29023       1330      2019     7043   167000       Honda
#
#       Model  Year           Trim                      Engine     BodyType  \
# 0       XJS  1995  2+2 Cabriolet     4.0L In-Line 6 Cylinder  Convertible
# 1   Mustang  1968          Stock              289 cu. in. V8        Coupe
# 2       911  2002     Turbo X-50                        3.6L        Coupe
# 3  Defender  1997            NaN  4.0 Liter Fuel Injected V8          NaN
# 4     Civic  2001             EX                         NaN        Coupe
#
#    NumCylinders DriveType
# 0             6       RWD
# 1             8       RWD
# 2             6       AWD
# 3             0       4WD
# 4             4       FWD

# %%
#Created histogram for price sold of all car data. Found mean and median for all car data.

cleaned_df["pricesold"].hist(bins=20)
plt.xlabel("Sale Price")
plt.ylabel("Number of Cars Sold")
plt.title("Car Sales by Price")
mean_numpy=np.mean(cleaned_df["pricesold"])
print(f"The mean sale price of used cars on ebay in 2019 and 2020 is {mean_numpy}")
median_numpy = np.median(cleaned_df["pricesold"])
print(f"The median sale price of used cars on ebay in 2019 and 2020 is {median_numpy}")
plt.savefig("images/all_hist.png")
# Out:
# The mean sale price of used cars on ebay in 2019 and 2020 is 10267.407047563805
# The median sale price of used cars on ebay in 2019 and 2020 is 6390.0

# %%
#Create histogram for all car sold data
quartiles= (cleaned_df["pricesold"]).quantile([.25, .5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[0.75]
iqr=upperq-lowerq

print(f"The lower quartile of price is: {lowerq}")
print(f"The upper quartile of price is: {upperq}")
print(f"The interquartile range of price is: {iqr}")
print(f"The the median of price is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")

fig1, ax1=plt.subplots()
ax1.boxplot(cleaned_df["pricesold"])
plt.ylabel("Sale Price")
plt.title("Sale Price for All Car Data")
plt.savefig("images/all_bw.png")
# Out:
# The lower quartile of price is: 2900.0
# The upper quartile of price is: 13450.0
# The interquartile range of price is: 10550.0
# The the median of price is: 6390.0
# Values below -12925.0 could be outliers.
# Values above 29275.0 could be outliers.

# %%
less_than_10df=pd.DataFrame(cleaned_df.loc[cleaned_df["pricesold"]<29275])
less_than_10df["pricesold"].hist(bins=10)
plt.xlabel("Sale Price")
plt.ylabel("Number of Cars Sold")
plt.title("Car Sales by Price Without Outliers")
plt.savefig("images/refined_hist.png")

# %% [markdown]
# COMPARE SALE PRICE AMONG MAKES

# %%
#Create box and whisker chart based on make

make_list = list(cleaned_df["Make"].unique())
# Create empty list to fill with tumor vol data (for plotting)
car_price_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for make in make_list:    
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    car_price = cleaned_df.loc[cleaned_df["Make"] == make, 'pricesold'] 
    
    # add subset 
    car_price_data.append(car_price)    
    
    # Determine outliers using upper and lower bounds   
    quartiles=car_price.quantile([.25, .5, .75])
    lowerq=quartiles[0.25]
    upperq=quartiles[0.75]
    iqr= upperq-lowerq    
    lower_bound= lowerq - (1.5*iqr)
    upper_bound=upperq+(1.5*iqr)
    outliers = car_price.loc[(car_price < lower_bound) | (car_price > upper_bound)]

    print(f"{make}'s potential outliers: {outliers.count()}")
    print(f"{make}'s' lower quartile of price is: {lowerq}")
    print(f"{make}'s upper quartile of price is: {upperq}")
    print(f"{make} interquartile range of price is: {iqr}")
    print(f"{make}'s' median sale price is: {quartiles[0.5]} ")
    print("--------------------------------------------------")

    #lower_bound = lowerq - (1.5*iqr)
    #upper_bound = upperq + (1.5*iqr)
    #print(f"Values below {lower_bound} could be outliers.")
    #print(f"Values above {upper_bound} could be outliers.")
# Out:
# Jaguar's potential outliers: 91
# Jaguar's' lower quartile of price is: 2405.0
# Jaguar's upper quartile of price is: 10500.0
# Jaguar's' interquartile range of price is: 8095.0
# Jaguar's' median sale price is: 5100.0
# --------------------------------------------------
# Ford's potential outliers: 754
# Ford's' lower quartile of price is: 3150.0
# Ford's upper quartile of price is: 14000.0
# Ford's' interquartile range of price is: 10850.0
# Ford's' median sale price is: 6890.0
# --------------------------------------------------
# Porsche's potential outliers: 74
# Porsche's' lower quartile of price is: 6422.5
# Porsche's upper quartile of price is: 31370.0
# Porsche's' interquartile range of price is: 24947.5
# Porsche's' median sale price is: 16000.0
# --------------------------------------------------
# Land Rover's potential outliers: 41
# Land Rover's' lower quartile of price is: 4000.0
# Land Rover's upper quartile of price is: 20200.0
# Land Rover's' interquartile range of price is: 16200.0
# Land Rover's' median sale price is: 9250.0
# --------------------------------------------------
# Honda's potential outliers: 185
# Honda's' lower quartile of price is: 1280.0
# Honda's upper quartile of price is: 7100.0
# Honda's' interquartile range of price is: 5820.0
# Honda's' median sale price is: 3050.0
# --------------------------------------------------
# Pontiac's potential outliers: 45
# Pontiac's' lower quartile of price is: 2952.5
# Pontiac's upper quartile of price is: 14900.0
# Pontiac's' interquartile range of price is: 11947.5
# Pontiac's' median sale price is: 7100.0
# --------------------------------------------------
# Jeep's potential outliers: 160
# Jeep's' lower quartile of price is: 3200.0
# Jeep's upper quartile of price is: 14000.0
# Jeep's' interquartile range of price is: 10800.0
# Jeep's' median sale price is: 7100.0
# --------------------------------------------------
# Chevrolet's potential outliers: 874
# Chevrolet's' lower quartile of price is: 3580.0
# Chevrolet's upper quartile of price is: 15622.5
# Chevrolet's' interquartile range of price is: 12042.5
# Chevrolet's' median sale price is: 7900.0
# --------------------------------------------------
# Nissan's potential outliers: 133
# Nissan's' lower quartile of price is: 1550.0
# Nissan's upper quartile of price is: 7900.0
# Nissan's' interquartile range of price is: 6350.0
# Nissan's' median sale price is: 3800.0
# --------------------------------------------------
# Chrysler's potential outliers: 93
# Chrysler's' lower quartile of price is: 1410.0
# Chrysler's upper quartile of price is: 7335.0
# Chrysler's' interquartile range of price is: 5925.0
# Chrysler's' median sale price is: 3200.0
# --------------------------------------------------
# Toyota's potential outliers: 364
# Toyota's' lower quartile of price is: 2480.0
# Toyota's upper quartile of price is: 10300.0
# Toyota's' interquartile range of price is: 7820.0
# Toyota's' median sale price is: 5200.0
# --------------------------------------------------
# Mercedes-Benz's potential outliers: 410
# Mercedes-Benz's' lower quartile of price is: 2827.5
# Mercedes-Benz's upper quartile of price is: 12000.0
# Mercedes-Benz's' interquartile range of price is: 9172.5
# Mercedes-Benz's' median sale price is: 6000.0
# --------------------------------------------------
# Dodge's potential outliers: 225
# Dodge's' lower quartile of price is: 2862.5
# Dodge's upper quartile of price is: 16000.0
# Dodge's' interquartile range of price is: 13137.5
# Dodge's' median sale price is: 6810.0
# --------------------------------------------------
# Cadillac's potential outliers: 137
# Cadillac's' lower quartile of price is: 3000.0
# Cadillac's upper quartile of price is: 14172.5
# Cadillac's' interquartile range of price is: 11172.5
# Cadillac's' median sale price is: 6900.0
# --------------------------------------------------
# Buick's potential outliers: 32
# Buick's' lower quartile of price is: 2200.0
# Buick's upper quartile of price is: 12800.0
# Buick's' interquartile range of price is: 10600.0
# Buick's' median sale price is: 5730.0
# --------------------------------------------------
# GMC's potential outliers: 109
# GMC's' lower quartile of price is: 3050.0
# GMC's upper quartile of price is: 14500.0
# GMC's' interquartile range of price is: 11450.0
# GMC's' median sale price is: 6600.0
# --------------------------------------------------
# BMW's potential outliers: 297
# BMW's' lower quartile of price is: 3000.0
# BMW's upper quartile of price is: 11235.0
# BMW's' interquartile range of price is: 8235.0
# BMW's' median sale price is: 6000.0
# --------------------------------------------------
# Volkswagen's potential outliers: 150
# Volkswagen's' lower quartile of price is: 2315.0
# Volkswagen's upper quartile of price is: 8400.0
# Volkswagen's' interquartile range of price is: 6085.0
# Volkswagen's' median sale price is: 4900.0
# --------------------------------------------------
# Lexus's potential outliers: 77
# Lexus's' lower quartile of price is: 3600.0
# Lexus's upper quartile of price is: 10900.0
# Lexus's' interquartile range of price is: 7300.0
# Lexus's' median sale price is: 6400.0
# --------------------------------------------------
# Lincoln's potential outliers: 70
# Lincoln's' lower quartile of price is: 2650.0
# Lincoln's upper quartile of price is: 11180.0
# Lincoln's' interquartile range of price is: 8530.0
# Lincoln's' median sale price is: 5050.0
# --------------------------------------------------
# Subaru's potential outliers: 96
# Subaru's' lower quartile of price is: 2000.0
# Subaru's upper quartile of price is: 7000.0
# Subaru's' interquartile range of price is: 5000.0
# Subaru's' median sale price is: 3700.0
# --------------------------------------------------
# Audi's potential outliers: 93
# Audi's' lower quartile of price is: 2870.0
# Audi's upper quartile of price is: 12600.0
# Audi's' interquartile range of price is: 9730.0
# Audi's' median sale price is: 6200.0
# --------------------------------------------------

# %%
fig6,ax1=plt.subplots(figsize=(10,5))
ax1.boxplot(car_price_data)
plt.show
ax1.set_xlabel("Make")
ax1.set_ylabel("Sale Price")
x= np.arange(1,23)
plt.xticks(x, list(cleaned_df["Make"].unique()), rotation=45)


plt.title("Sale Price by Make")


plt.show()
plt.savefig("images/price_by_make_bw.png")

# %% [markdown]
# COMPARE SALE PRICE OF 18 DESIRED MODELS

# %%
#Create data frame using only desired models

model_df= pd.DataFrame(cleaned_df.loc[(cleaned_df["Model"] == "A4")
                                     |(cleaned_df["Model"] == "300 Series")
                                     |(cleaned_df["Model"] == "Charger")
                                     |(cleaned_df["Model"] == "Sierra 1500")
                                     |(cleaned_df["Model"] == "Yukon")
                                     |(cleaned_df["Model"] == "Civic")
                                     |(cleaned_df["Model"] == "Accord")
                                     |(cleaned_df["Model"] == "Odyssey")
                                     |(cleaned_df["Model"] == "Wrangler")
                                     |(cleaned_df["Model"] == "Grand Cherokee")
                                     |(cleaned_df["Model"] == "RX")
                                     |(cleaned_df["Model"] == "SL-Class")
                                     |(cleaned_df["Model"] == "E-Class")
                                     |(cleaned_df["Model"] == "Forester")
                                     |(cleaned_df["Model"] == "Outback")
                                     |(cleaned_df["Model"] == "Legacy")
                                     |(cleaned_df["Model"] == "Impreza")
                                     |(cleaned_df["Model"] == "WRX")
                                      
                                     ])
                      
model_df.head()
# Out:
#     Unnamed: 0     ID  pricesold  yearsold  zipcode  Mileage      Make  \
# 4            8  29023       1330      2019     7043   167000     Honda
# 6           11  72418      14100      2019     7014   109500      Jeep
# 12          24  45651       5390      2019     7840   134000  Chrysler
# 17          33  84279       3400      2019    60542   182000      Jeep
# 23          44  55855      49810      2019    13039     2640     Dodge
#
#              Model  Year         Trim                     Engine BodyType  \
# 4            Civic  2001           EX                        NaN    Coupe
# 6         Wrangler  2012    Unlimited                       3.6L      SUV
# 12      300 Series  2009          NaN                  5.7L HEMI      NaN
# 17  Grand Cherokee  2005          NaN  5.7 liter 8 Cylinder Hemi      SUV
# 23         Charger  2016  SRT Hellcat          6.2L Supercharged    Sedan
#
#     NumCylinders DriveType
# 4              4       FWD
# 6              6       4WD
# 12             8       AWD
# 17             8       4WD
# 23             8       RWD

# %%
#Create box and whisker for desired models

model_list = list(model_df["Model"].unique())
# Create empty list to fill with tumor vol data (for plotting)
car_price_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for model in model_list:    
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    car_price = model_df.loc[model_df["Model"] == model, 'pricesold'] 
    
    # add subset 
    car_price_data.append(car_price)    
    
    # Determine outliers using upper and lower bounds   
    quartiles=car_price.quantile([.25, .5, .75])
    lowerq=quartiles[0.25]
    upperq=quartiles[0.75]
    iqr= upperq-lowerq    
    lower_bound= lowerq - (1.5*iqr)
    upper_bound=upperq+(1.5*iqr)
    outliers = car_price.loc[(car_price < lower_bound) | (car_price > upper_bound)]

    print(f"{model}'s potential outliers: {outliers.count()}")
    print(f"{model}'s' lower quartile of price is: {lowerq}")
    print(f"{model}'s upper quartile of price is: {upperq}")
    print(f"{model} interquartile range of price is: {iqr}")
    print(f"{model}'s' median sale price is: {quartiles[0.5]} ")
    print("--------------------------------------------------")

    #lower_bound = lowerq - (1.5*iqr)
    #upper_bound = upperq + (1.5*iqr)
    #print(f"Values below {lower_bound} could be outliers.")
    #print(f"Values above {upper_bound} could be outliers.")
# Out:
# Civic's potential outliers: 68
# Civic's' lower quartile of price is: 1050.0
# Civic's upper quartile of price is: 5100.0
# Civic interquartile range of price is: 4050.0
# Civic's' median sale price is: 2450.0
# --------------------------------------------------
# Wrangler's potential outliers: 46
# Wrangler's' lower quartile of price is: 6050.0
# Wrangler's upper quartile of price is: 18995.0
# Wrangler interquartile range of price is: 12945.0
# Wrangler's' median sale price is: 10600.0
# --------------------------------------------------
# 300 Series's potential outliers: 2
# 300 Series's' lower quartile of price is: 2500.0
# 300 Series's upper quartile of price is: 15715.0
# 300 Series interquartile range of price is: 13215.0
# 300 Series's' median sale price is: 6350.0
# --------------------------------------------------
# Grand Cherokee's potential outliers: 13
# Grand Cherokee's' lower quartile of price is: 1845.0
# Grand Cherokee's upper quartile of price is: 16600.0
# Grand Cherokee interquartile range of price is: 14755.0
# Grand Cherokee's' median sale price is: 4000.0
# --------------------------------------------------
# Charger's potential outliers: 12
# Charger's' lower quartile of price is: 4912.5
# Charger's upper quartile of price is: 24362.5
# Charger interquartile range of price is: 19450.0
# Charger's' median sale price is: 11075.0
# --------------------------------------------------
# SL-Class's potential outliers: 83
# SL-Class's' lower quartile of price is: 4650.0
# SL-Class's upper quartile of price is: 12100.0
# SL-Class interquartile range of price is: 7450.0
# SL-Class's' median sale price is: 7450.0
# --------------------------------------------------
# Accord's potential outliers: 49
# Accord's' lower quartile of price is: 960.0
# Accord's upper quartile of price is: 6350.0
# Accord interquartile range of price is: 5390.0
# Accord's' median sale price is: 2320.0
# --------------------------------------------------
# Yukon's potential outliers: 6
# Yukon's' lower quartile of price is: 3120.0
# Yukon's upper quartile of price is: 21300.0
# Yukon interquartile range of price is: 18180.0
# Yukon's' median sale price is: 6300.0
# --------------------------------------------------
# E-Class's potential outliers: 46
# E-Class's' lower quartile of price is: 2370.0
# E-Class's upper quartile of price is: 10000.0
# E-Class interquartile range of price is: 7630.0
# E-Class's' median sale price is: 4840.0
# --------------------------------------------------
# Odyssey's potential outliers: 15
# Odyssey's' lower quartile of price is: 1680.0
# Odyssey's upper quartile of price is: 9345.0
# Odyssey interquartile range of price is: 7665.0
# Odyssey's' median sale price is: 3780.0
# --------------------------------------------------
# WRX's potential outliers: 0
# WRX's' lower quartile of price is: 5200.0
# WRX's upper quartile of price is: 17300.0
# WRX interquartile range of price is: 12100.0
# WRX's' median sale price is: 12000.0
# --------------------------------------------------
# RX's potential outliers: 20
# RX's' lower quartile of price is: 3900.0
# RX's upper quartile of price is: 10600.0
# RX interquartile range of price is: 6700.0
# RX's' median sale price is: 5900.0
# --------------------------------------------------
# Forester's potential outliers: 17
# Forester's' lower quartile of price is: 1620.0
# Forester's upper quartile of price is: 5435.0
# Forester interquartile range of price is: 3815.0
# Forester's' median sale price is: 3115.0
# --------------------------------------------------
# Sierra 1500's potential outliers: 27
# Sierra 1500's' lower quartile of price is: 3527.5
# Sierra 1500's upper quartile of price is: 14300.0
# Sierra 1500 interquartile range of price is: 10772.5
# Sierra 1500's' median sale price is: 6450.0
# --------------------------------------------------
# Outback's potential outliers: 20
# Outback's' lower quartile of price is: 2242.5
# Outback's upper quartile of price is: 6480.0
# Outback interquartile range of price is: 4237.5
# Outback's' median sale price is: 3565.0
# --------------------------------------------------
# A4's potential outliers: 20
# A4's' lower quartile of price is: 1855.0
# A4's upper quartile of price is: 6250.0
# A4 interquartile range of price is: 4395.0
# A4's' median sale price is: 3860.0
# --------------------------------------------------
# Impreza's potential outliers: 10
# Impreza's' lower quartile of price is: 1910.0
# Impreza's upper quartile of price is: 6875.0
# Impreza interquartile range of price is: 4965.0
# Impreza's' median sale price is: 3260.0
# --------------------------------------------------
# Legacy's potential outliers: 6
# Legacy's' lower quartile of price is: 1200.0
# Legacy's upper quartile of price is: 3355.0
# Legacy interquartile range of price is: 2155.0
# Legacy's' median sale price is: 2080.0
# --------------------------------------------------

# %%
fig6,ax1=plt.subplots(figsize=(10,5))
ax1.boxplot(car_price_data)
plt.show
ax1.set_xlabel("Model")
ax1.set_ylabel("Sale Price")
x= np.arange(1,19)
plt.xticks(x, list(model_df["Model"].unique()), rotation=45)


plt.title("Sale Price by Model")


plt.show()
plt.savefig("images/price_by_model_bw.png")

# %% [markdown]
# COMPARE MOST COMMON SALE PRICE OF THREE MAKES OF CIVIC

# %%
civic_df= pd.DataFrame(cleaned_df.loc[cleaned_df["Model"] == "Civic"])

# %%
civic_df["pricesold"].hist(bins=10)
mean_numpy=np.mean(civic_df["pricesold"])
print(f"The mean sale price of Civics on ebay in 2019 and 2020 is {mean_numpy}")
median_numpy = np.median(civic_df["pricesold"])
print(f"The median sale price of Civics on ebay in 2019 and 2020 is {median_numpy}")
plt.xlabel("Sale Price")
plt.ylabel("Number of Cars Sold")
plt.title("Honda Civic Sales by Price")
plt.savefig("images/honda_civic_hist.png")
# Out:
# The mean sale price of Civics on ebay in 2019 and 2020 is 4323.352353780314
# The median sale price of Civics on ebay in 2019 and 2020 is 2450.0

# %%
accord_df= pd.DataFrame(cleaned_df.loc[cleaned_df["Model"] == "Accord"])

# %%
accord_df["pricesold"].hist(bins=10)
mean_numpy=np.mean(accord_df["pricesold"])
print(f"The mean sale price of Accords on ebay in 2019 and 2020 is {mean_numpy}")
median_numpy = np.median(accord_df["pricesold"])
print(f"The median sale price of Accords on ebay in 2019 and 2020 is {median_numpy}")
plt.xlabel("Sale Price")
plt.ylabel("Number of Cars Sold")
plt.title("Honda Accord Sales by Price")
plt.savefig("images/honda_accord_hist.png")
# Out:
# The mean sale price of Accords on ebay in 2019 and 2020 is 4850.625978090767
# The median sale price of Accords on ebay in 2019 and 2020 is 2320.0

# %%
odyssey_df= pd.DataFrame(cleaned_df.loc[cleaned_df["Model"] == "Odyssey"])

# %%
odyssey_df["pricesold"].hist(bins=10)
mean_numpy=np.mean(odyssey_df["pricesold"])
print(f"The mean sale price of Odysseys on ebay in 2019 and 2020 is {mean_numpy}")
median_numpy = np.median(odyssey_df["pricesold"])
print(f"The median sale price of Odysseyss on ebay in 2019 and 2020 is {median_numpy}")
plt.xlabel("Sale Price")
plt.ylabel("Number of Cars Sold")
plt.title("Honda Odyssey Sales by Price")
plt.savefig("images/honda_odyssey_hist.png")
# Out:
# The mean sale price of Odysseys on ebay in 2019 and 2020 is 6670.555555555556
# The median sale price of Odysseyss on ebay in 2019 and 2020 is 3780.0
